# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 716.0/716.0 kB 5.1 MB/s eta 0:00:00
# ...

# %%
# !pip install easyocr
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 11.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.3/908.3 kB 54.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 29.1 MB/s eta 0:00:00
# ...

# %%
import cv2  # Import OpenCV library for image processing
import numpy as np  # Import NumPy library for numerical operations
import matplotlib.pyplot as plt  # Import Matplotlib library for visualization
from ultralytics import YOLO  # Import YOLO object detection model from Ultralytics
import easyocr  # Import EasyOCR library for optical character recognition

# %% [markdown]
# # **Load model**

# %%
model = YOLO("yolov8s.yaml")  # build a new model from scratch

# %%
# Use the model
model.train(data="/content/drive/MyDrive/config.yaml", epochs=80,batch=32,imgsz=640,save=True)  # train the model
# Out:
# Ultralytics YOLOv8.1.14 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# to get the model evaluation
metrics = model.val()
# Out:
# Ultralytics YOLOv8.1.14 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# ...
# 100%|██████████| 755k/755k [00:00<00:00, 57.3MB/s]
# val: Scanning /content/drive/MyDrive/Data_car/labels/val.cache... 499 images, 0 backgrounds, 0 corrupt: 100%|██████████| 499/499 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 32/32 [05:35<00:00, 10.48s/it]
#                    all        499        507      0.992      0.992      0.995      0.922
# Speed: 5.0ms preprocess, 620.5ms inference, 0.0ms loss, 0.5ms postprocess per image
# Results saved to runs/detect/val2

# %%
# Load class list from file
with open("/content/drive/MyDrive/mydata.txt", "r") as file:
    class_list = file.read().split("\n")

# %%
# Initialize YOLO model
model = YOLO('/content/drive/MyDrive/best.pt')

# %%
# Read the image
frame = cv2.imread('/content/drive/MyDrive/Data_car/images/test/1429.jpg')
frame = cv2.resize(frame, (640, 640))
frame_copy = frame.copy()

# %%
# Perform object detection
results = model.predict(frame)
bounding_boxes = results[0].boxes.data
class_confidences = results[0].boxes.conf.tolist()
# Out:
# 0: 640x640 1 car name plate, 16.6ms
# Speed: 5.1ms preprocess, 16.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)

# %%
# Process detected objects
for box, confidence in zip(bounding_boxes, class_confidences):
    x1, y1, x2, y2, _, class_index = map(int, box)
    class_name = class_list[class_index]
    # Crop the area within the bounding box
    cx, cy = (x1 + x2) // 2, (y1 + y2) // 2

    color = (255, 0, 0)  # blue for car name plate


    cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)

    cv2.putText(frame, f'Egycar name plate: {confidence:.2f}', (x1, y1 - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)


# Convert the image to RGB (OpenCV uses BGR by default)
frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

# Display the image with bounding boxes using Matplotlib
plt.figure(figsize=(10, 10))
plt.imshow(frame_rgb)
plt.axis('off')  # Turn off axis labels
plt.show()

# %%
cropped_images = {}  # Dictionary to store cropped images by class name

for box in bounding_boxes:
    x1, y1, x2, y2, _, class_index = map(int, box)
    class_name = class_list[class_index]

    # Crop the area within the bounding box
    cropped_image = frame[y1:y2, x1:x2]

    cropped_images.setdefault(class_name, []).append(cropped_image)

# Display the cropped images
plt.figure(figsize=(10, 10))
for i, (class_name, images) in enumerate(cropped_images.items(), start=1):
    for j, cropped_image in enumerate(images, start=1):
        plt.subplot(len(cropped_images), max(len(images), 1), i + j - 1)
        plt.imshow(cv2.cvtColor(cropped_image, cv2.COLOR_BGR2RGB))
        plt.title(f"{class_name}_{j}")
        plt.axis('off')

plt.tight_layout()
plt.show()

# %%
reader = easyocr.Reader(['ar'])  # Initialize EasyOCR with Arabic as the language

# Loop through cropped images and perform OCR
for class_name, images in cropped_images.items():
    for j, cropped_image in enumerate(images, start=1):
        results = reader.readtext(cropped_image)

        # Iterate over OCR results for each cropped image
        for detection in results:
            print(detection[1])  # Detected text
# Out:
# بط ل ٥٥٥٥
